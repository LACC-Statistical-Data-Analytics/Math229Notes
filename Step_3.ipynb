# %% [markdown]
# ![logo.gif](data:image/gif;base64,...)

# %% [markdown]
# # **LACC STEM Core Summer Bridge Program**
# ---
# The **"6-Step Method"** is a research methodology developed by Roy (1996) that is commonly used in the field of library and information science. The method provides a structured approach to conducting research, with a particular focus on qualitative research. The six steps are as follows:
#
# 1.   Select the research problem: The first step in the 6-Step Method is to select a research problem. This involves identifying a research question or problem that is of interest to the researcher.
# 2.   Define the research question: Once a research problem has been selected, the researcher must define the research question that they are seeking to answer. This involves specifying the scope and focus of the research.
# 3.   Plan the research design: The third step in the 6-Step Method involves planning the research design. This involves selecting appropriate research methods, such as interviews, surveys, or observations, and developing a plan for collecting and analyzing data.
# 4.   Collect the data: The fourth step in the 6-Step Method is to collect the data. This involves implementing the research plan and collecting data from participants or other sources.
# 5.   Analyze the data: Once the data has been collected, the fifth step in the 6-Step Method is to analyze the data. This involves identifying patterns and themes in the data and drawing conclusions based on the analysis.
# 6.   Present the findings: The final step in the 6-Step Method is to present the findings. This involves communicating the results of the research in a clear and concise manner, using appropriate methods such as written reports or oral presentations.
#
#
# Overall, the 6-Step Method provides a structured approach to conducting research that can help researchers to ensure that their research is thorough, systematic, and focused. It is particularly useful for qualitative research, where there is a need for a structured approach to collecting and analyzing data.
#
# ---
#
# ## Used Car Investigation
# **6 Step Method:** Steps 3 (Part 1)
#
# In-Class Activity Notebook
#
# ---
#
# **Step 3: Explore the Data**
#
# Our goal is to explore the data by creating a scatterplot.
#
# ---

# %% [markdown]
# 1. Pick one of the two numerical variables you collected to serve as your explanatory (predictor) variable. Which variable did you choose and why?

# %% [markdown]
# **The answer will vary. Most students will choose either age/model year or mileage. Generally, students should create scatterplots and pick the one that looks more linear.**

# %% [markdown]
# 2. When we make the scatterplot, will that variable go on the x-axis or the y-axis? What variable will go on the other axis?

# %% [markdown]
# **The explanatory variable will go on the x-axis and the price of the car (response variable) will go on the y-axis.**

# %% [markdown]
# 3. Create the scatterplot in using Python below

# %%
from IPython.display import IFrame

# Replace with your Google Sheets embed URL
embed_url = 'https://docs.google.com/spreadsheets/d/1mC2k0Ss303qXJUQYFreqoA0W6f3kbGVTv8ml59d0GRM/edit?usp=sharing'

# Create an IFrame to embed the Google Sheets
IFrame(embed_url, width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1mC2k0Ss303qXJUQYFreqoA0W6f3kbGVTv8ml59d0GRM/edit?usp=sharing"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Correct URL for exporting Google Sheets to CSV
csv_url = 'https://docs.google.com/spreadsheets/d/1mC2k0Ss303qXJUQYFreqoA0W6f3kbGVTv8ml59d0GRM/gviz/tq?tqx=out:csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_url)

# Convert columns to numeric values if needed
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Mileage'] = pd.to_numeric(df['Mileage'], errors='coerce')


# Drop rows with NaN values that resulted from conversion issues
df = df.dropna(subset=['Price', 'Mileage'])

# Create a scatter plot of Price vs Mileage
plt.figure(figsize=(10, 6))
plt.scatter(df['Mileage'], df['Price'], alpha=0.5, color='blue', edgecolors='w', s=100)
plt.title('Scatter Plot of Price vs Mileage')
plt.xlabel('Mileage')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %% [markdown]
# ---
#
# #### **Now it's your turn! Try Problem on your own.**
#
# ---

# %% [markdown]
# 4. What does each point on your scatterplot represent?

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 5. Do you notice any outliers? Where are they on the scatterplot? Why do you suspect they are outliers?

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 6. Is the association between the two variables positive or negative? Or is it difficult to tell? Explain your answer.

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 7. Does the association appear to be linear or nonlinear? Explain your answer.

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 8. Without using any numbers, describe how strong the association is. Are there areas of the graph where the association is stronger or weaker?

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 9. According to Python, what is the correlation between the two variables?

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 10. Are the sign (positive or negative) and magnitude (how close the value is to -1 or 1) of the correlation coefficient meaningful for describing the association between the two variables? If so, explain what they mean. If not, explain why the correlation coefficient would not be applicable to describe your data.

# %% [markdown]
# **Enter your answer here**

# %% [markdown]
# 11. In Python, indicate different groups of cars (based on your categorical variable) on the scatterplot using different colors. What differences do you notice between the groups? Look at differences in the explanatory variable, differences in the price, and differences in the relationship between the variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# URL for exporting Google Sheets to CSV
csv_url = 'https://docs.google.com/spreadsheets/d/1mC2k0Ss303qXJUQYFreqoA0W6f3kbGVTv8ml59d0GRM/gviz/tq?tqx=out:csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_url)

# Convert 'Price' and 'Mileage' columns to numeric values
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['Mileage'] = pd.to_numeric(df['Mileage'], errors='coerce')

# Drop rows with NaN values in 'Price' or 'Mileage'
df = df.dropna(subset=['Price', 'Mileage'])

# Define a dictionary that maps condition values to colors
colors = {'Good': 'blue', 'Like New': 'green'}

# Check if all conditions in the DataFrame are covered by the color dictionary
df['Condition'] = df['Condition'].apply(lambda x: colors.get(x, 'gray'))  # Default to gray for unexpected values

# Create a scatter plot of Price vs Mileage, with color based on the Condition
plt.figure(figsize=(12, 8))

# Scatter plot with color mapping
plt.scatter(df['Mileage'], df['Price'],
            c=df['Condition'],
            alpha=0.7,
            edgecolors='w',
            s=100)

# Add a legend
handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor=color, markersize=10, linestyle='') for color in colors.values()]
plt.legend(handles, colors.keys(), title='Condition')

plt.xlabel('Mileage')
plt.ylabel('Price in ($)')
plt.title('Price vs Mileage Scatter Plot (Color by Condition)')
plt.grid(True)
plt.show()

# %% [markdown]
# <img src="https://media.giphy.com/media/26ufnwz3wDUli7GU0/giphy.gif">

# %% [markdown]
# ![Business+Card.jpg.gif](data:image/gif;base64,...)

# %% [markdown]
# ![CopyRight.gif](data:image/gif;base64,...)
