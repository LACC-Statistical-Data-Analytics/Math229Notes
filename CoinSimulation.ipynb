# %% [markdown]
# ![LACC.jpg](attachment:LACC.jpg)

# %% [markdown]
# <font color=Blue>**Math 229: Statistics for Data Science**</font>
#
# <font color=Blue>**Professor: Edward Pineda-Castro**</font>
#
# <font color=Blue>**Los Angeles City College**</font>

# %% [markdown]
#  <div class="alert alert-block alert-info">
# <b>This code:</b> Simulates a coin flip.
# </div>

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# Set the number of coin flips
num_flips = 10

# Initialize counters for heads and tails
heads_count = 0
tails_count = 0

# Simulate coin flips
for _ in range(num_flips):
    # Generate a random number: 0 for tails, 1 for heads
    coin_result = random.randint(0, 1)
    
    # Update the counters based on the coin result
    if coin_result == 0:
        tails_count += 1
    else:
        heads_count += 1

# Calculate the probabilities of heads and tails
prob_heads = heads_count / num_flips
prob_tails = tails_count / num_flips

# Print the simulation results and probabilities
print("Heads count:", heads_count)
print("Tails count:", tails_count)
print("Probability of heads:", prob_heads)
print("Probability of tails:", prob_tails)

# Create a bar plot to visualize the probabilities
outcomes = ("Heads", "Tails")
probabilities = [prob_heads, prob_tails]
y_pos = np.arange(len(outcomes))

# Create bars
plt.bar(y_pos, probabilities, color=["blue", "red"])

# Add labels and title
plt.xlabel("Outcomes")
plt.ylabel("Probability")
plt.title("Probability of Coin Flips")

# Add outcome names on the x-axis
plt.xticks(y_pos, outcomes)

# Show the plot
plt.show()
# Out:
# Heads count: 7
# Tails count: 3
# Probability of heads: 0.7
# Probability of tails: 0.3

# %% [markdown]
# <img src="https://media.giphy.com/media/XtdLpKOzoxJCzlFY4n/giphy.gif">
#
# <font color=Blue>**Instructor:** Edward Pineda-Castro, Los Angeles City College </font>
#
# <font color=Blue>  Math 229 Statistics for Data Science Lecuture Notes  </font>
